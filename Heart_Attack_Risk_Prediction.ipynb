# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
# !pip install seaborn
# Out:
# ...
# [notice] A new release of pip is available: 26.0 -> 26.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

print("Libraries imported successfully!")
# Out:
# Libraries imported successfully!

# %%
import os

project_path = r"E:\Heart Attack Prediction"

os.chdir(project_path)

print("Current Folder:")
print(os.getcwd())

print("\nFiles:")
print(os.listdir())
# Out:
# Current Folder:
# E:\Heart Attack Prediction
#
# Files:
# ['heart_attack_prediction_india.csv', 'heart_attack_risk_model.pkl', 'heart_attack_scaler.pkl']

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\asoka

# %%
import os

folder_path = r"E:\Heart Attack Prediction"

print(os.listdir(folder_path))
# Out:
# ['heart_attack_prediction_india.csv', 'heart_attack_risk_model.pkl', 'heart_attack_scaler.pkl']

# %%
import os
import pandas as pd

folder_path = r"E:\Heart Attack Prediction"

csv_files = [file for file in os.listdir(folder_path)
             if file.lower().endswith(".csv")]

print("CSV Files Found:")
print(csv_files)
# Out:
# CSV Files Found:
# ['heart_attack_prediction_india.csv']

# %%
file_path = os.path.join(folder_path, csv_files[0])

df = pd.read_csv(file_path)

print("Dataset loaded successfully!")
# Out:
# Dataset loaded successfully!

# %%
print("Dataset Shape:", df.shape)

print("\nFirst 5 Rows:")
display(df.head())
# Out:
# Dataset Shape: (7000, 22)
#
# First 5 Rows:
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0   69       0                4                     109          487
# 1   32       0                2                     125          170
# 2   89       0                2                     186          543
# 3   78       0                2                     104          367
# 4   38       1                1                     151          158
#
#    Fasting Blood Sugar (> 120 mg/dL)  Resting ECG Results  \
# 0                                  1                    1
# 1                                  0                    1
# 2                                  1                    0
# 3                                  0                    0
# 4                                  1                    0
#
#    Max Heart Rate Achieved  Exercise-Induced Angina  Old Peak (ST Depression)  \
# ...

# %%
print("Columns:")
print(df.columns.tolist())
# Out:
# Columns:
# ['Age', 'Gender', 'Chest Pain Type', 'Resting Blood Pressure', 'Cholesterol', 'Fasting Blood Sugar (> 120 mg/dL)', 'Resting ECG Results', 'Max Heart Rate Achieved', 'Exercise-Induced Angina', 'Old Peak (ST Depression)', 'Slope of Peak Exercise ST Segment', 'Number of Major Vessels (0-3)', 'Thalassemia', 'Smoking History', 'Obesity (BMI > 30)', 'Hypertension History', 'Diabetes History', 'Alcohol Consumption', 'Physical Activity', 'Stress Levels', 'Family History of Heart Disease', 'Heart Attack Risk']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7000 entries, 0 to 6999
# Data columns (total 22 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Age                                7000 non-null   int64
#  1   Gender                             7000 non-null   int64
#  2   Chest Pain Type                    7000 non-null   int64
#  3   Resting Blood Pressure             7000 non-null   int64
#  4   Cholesterol                        7000 non-null   int64
#  5   Fasting Blood Sugar (> 120 mg/dL)  7000 non-null   int64
#  6   Resting ECG Results                7000 non-null   int64
#  7   Max Heart Rate Achieved            7000 non-null   int64
#  8   Exercise-Induced Angina            7000 non-null   int64
#  9   Old Peak (ST Depression)           7000 non-null   float64
#  10  Slope of Peak Exercise ST Segment  7000 non-null   int64
# ...

# %%
print("Missing Values:")
print(df.isnull().sum())
# Out:
# Missing Values:
# Age                                  0
# Gender                               0
# Chest Pain Type                      0
# Resting Blood Pressure               0
# Cholesterol                          0
# Fasting Blood Sugar (> 120 mg/dL)    0
# Resting ECG Results                  0
# Max Heart Rate Achieved              0
# Exercise-Induced Angina              0
# Old Peak (ST Depression)             0
# Slope of Peak Exercise ST Segment    0
# Number of Major Vessels (0-3)        0
# Thalassemia                          0
# Smoking History                      0
# Obesity (BMI > 30)                   0
# Hypertension History                 0
# Diabetes History                     0
# Alcohol Consumption                  0
# Physical Activity                    0
# Stress Levels                        0
# Family History of Heart Disease      0
# Heart Attack Risk                    0
# dtype: int64

# %%
print("Duplicate Rows:", df.duplicated().sum())
# Out:
# Duplicate Rows: 0

# %%
print("COLUMN NAMES")
print("=" * 50)

for i, column in enumerate(df.columns, 1):
    print(i, ":", column)

print("\nDATA TYPES")
print("=" * 50)

print(df.dtypes)
# Out:
# COLUMN NAMES
# ...
# 1 : Age
# 2 : Gender
# 3 : Chest Pain Type
# 4 : Resting Blood Pressure
# 5 : Cholesterol
# 6 : Fasting Blood Sugar (> 120 mg/dL)
# 7 : Resting ECG Results
# 8 : Max Heart Rate Achieved
# 9 : Exercise-Induced Angina
# 10 : Old Peak (ST Depression)
# 11 : Slope of Peak Exercise ST Segment
# 12 : Number of Major Vessels (0-3)
# 13 : Thalassemia
# 14 : Smoking History
# 15 : Obesity (BMI > 30)
# 16 : Hypertension History
# 17 : Diabetes History
# 18 : Alcohol Consumption
# 19 : Physical Activity
# 20 : Stress Levels
# 21 : Family History of Heart Disease
# 22 : Heart Attack Risk
#
# DATA TYPES
# ...
# Age                                    int64
# Gender                                 int64
# Chest Pain Type                        int64
# Resting Blood Pressure                 int64
# Cholesterol                            int64
# Fasting Blood Sugar (> 120 mg/dL)      int64
# Resting ECG Results                    int64
# Max Heart Rate Achieved                int64
# ...

# %%
missing = df.isnull().sum()

print("Missing Values")
print("=" * 50)

print(missing[missing > 0])
# Out:
# Missing Values
# ...
# Series([], dtype: int64)

# %%
print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

display(df.head())
# Out:
# Rows: 7000
# Columns: 22
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0   69       0                4                     109          487
# 1   32       0                2                     125          170
# 2   89       0                2                     186          543
# 3   78       0                2                     104          367
# 4   38       1                1                     151          158
#
#    Fasting Blood Sugar (> 120 mg/dL)  Resting ECG Results  \
# 0                                  1                    1
# 1                                  0                    1
# 2                                  1                    0
# 3                                  0                    0
# 4                                  1                    0
#
#    Max Heart Rate Achieved  Exercise-Induced Angina  Old Peak (ST Depression)  \
# 0                      122                        1                      3.51
# ...

# %%
# Check unique values in each column

for column in df.columns:
    print(f"\n{column}")
    print("Unique values:", df[column].unique())
    print("Number of unique values:", df[column].nunique())
# Out:
# Age
# Unique values: [69 32 89 78 38 92 41 20 39 70 19 47 55 81 77 50 93 75 66 76 59 97 79 64
#  68 72 24 90 56 35 21 31 26 88 61 25 52 95 98 53 67 23 71 80 51 91 65 57
#  99 43 58 46 62 82 18 28 22 45 29 40 54 44 96 94 60 30 49 83 74 87 73 36
#  85 34 86 33 37 84 48 42 63 27]
# Number of unique values: 82
#
# Gender
# Unique values: [0 1]
# Number of unique values: 2
#
# Chest Pain Type
# Unique values: [4 2 1 3]
# Number of unique values: 4
#
# Resting Blood Pressure
# Unique values: [109 125 186 104 151 199  92 182 180  94 145 120 175 124 160 159 115  90
#  172  96 165 173 176 114 183 148 150 118 184 107 130 108  93 154 143 153
#  161 168 139 192 111 169  91 105 156 119 144 155 188 146 158 123 187 142
#  103 149 197 132 196 152 127 134 140 131 113 126 100 167 112 174 189 198
#  133 110 136 194 157 163 166 193 121  95 102 177 162 116 117 141 147  97
#  164  98 181 185 171 191 137 122 106 178  99 129 195 101 128 138 170 190
#  135 179]
# Number of unique values: 110
#
# Cholesterol
# ...

# %%
print("Heart Attack Risk Distribution")
print("=" * 40)

print(df["Heart Attack Risk"].value_counts())

print("\nPercentage:")
print(df["Heart Attack Risk"].value_counts(normalize=True) * 100)
# Out:
# Heart Attack Risk Distribution
# ...
# Heart Attack Risk
# 1    3503
# 0    3497
# Name: count, dtype: int64
#
# Percentage:
# Heart Attack Risk
# 1    50.042857
# 0    49.957143
# Name: proportion, dtype: float64

# %%
plt.figure(figsize=(7, 5))

sns.countplot(x="Heart Attack Risk", data=df)

plt.title("Heart Attack Risk Distribution")
plt.xlabel("Heart Attack Risk")
plt.ylabel("Number of Patients")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.histplot(data=df, x="Age", bins=20, kde=True)

plt.title("Age Distribution of Patients")
plt.xlabel("Age")
plt.ylabel("Number of Patients")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Heart Attack Risk",
    y="Age"
)

plt.title("Age Distribution by Heart Attack Risk")
plt.xlabel("Heart Attack Risk")
plt.ylabel("Age")
plt.show()

# %%
plt.figure(figsize=(7, 5))

sns.countplot(
    data=df,
    x="Gender",
    hue="Heart Attack Risk"
)

plt.title("Gender vs Heart Attack Risk")
plt.xlabel("Gender")
plt.ylabel("Number of Patients")
plt.legend(title="Heart Attack Risk")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Heart Attack Risk",
    y="Cholesterol"
)

plt.title("Cholesterol Levels by Heart Attack Risk")
plt.xlabel("Heart Attack Risk")
plt.ylabel("Cholesterol")
plt.show()

# %%
plt.figure(figsize=(8, 5))

sns.boxplot(
    data=df,
    x="Heart Attack Risk",
    y="Resting Blood Pressure"
)

plt.title("Resting Blood Pressure by Heart Attack Risk")
plt.xlabel("Heart Attack Risk")
plt.ylabel("Resting Blood Pressure")
plt.show()

# %%
plt.figure(figsize=(16, 12))

correlation = df.corr(numeric_only=True)

sns.heatmap(
    correlation,
    annot=True,
    fmt=".2f",
    cmap="coolwarm",
    linewidths=0.5
)

plt.title("Correlation Heatmap of Heart Attack Risk Dataset")
plt.show()

# %%
X = df.drop("Heart Attack Risk", axis=1)
y = df["Heart Attack Risk"]

print("Features Shape:", X.shape)
print("Target Shape:", y.shape)
# Out:
# Features Shape: (7000, 21)
# Target Shape: (7000,)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

print("Training Features:", X_train.shape)
print("Testing Features:", X_test.shape)
print("Training Target:", y_train.shape)
print("Testing Target:", y_test.shape)
# Out:
# Training Features: (5600, 21)
# Testing Features: (1400, 21)
# Training Target: (5600,)
# Testing Target: (1400,)

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)

print("Feature scaling completed successfully!")
# Out:
# Feature scaling completed successfully!

# %%
print("Scaled Training Data Shape:", X_train_scaled.shape)
print("Scaled Testing Data Shape:", X_test_scaled.shape)
# Out:
# Scaled Training Data Shape: (5600, 21)
# Scaled Testing Data Shape: (1400, 21)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

# %%
models = {
    "Logistic Regression": LogisticRegression(max_iter=1000, random_state=42),
    "Decision Tree": DecisionTreeClassifier(random_state=42),
    "Random Forest": RandomForestClassifier(n_estimators=100, random_state=42),
    "K-Nearest Neighbors": KNeighborsClassifier(n_neighbors=5),
    "Support Vector Machine": SVC(random_state=42)
}

print("Models created successfully!")
# Out:
# Models created successfully!

# %%
trained_models = {}

for name, model in models.items():
    model.fit(X_train_scaled, y_train)
    trained_models[name] = model
    print(f"{name} trained successfully!")
# Out:
# Logistic Regression trained successfully!
# Decision Tree trained successfully!
# Random Forest trained successfully!
# K-Nearest Neighbors trained successfully!
# Support Vector Machine trained successfully!

# %%
from sklearn.metrics import accuracy_score

results = []

for name, model in trained_models.items():
    y_pred = model.predict(X_test_scaled)
    accuracy = accuracy_score(y_test, y_pred)

    results.append({
        "Model": name,
        "Accuracy": round(accuracy * 100, 2)
    })

results_df = pd.DataFrame(results).sort_values(
    by="Accuracy",
    ascending=False
).reset_index(drop=True)

results_df
# Out:
#                     Model  Accuracy
# 0  Support Vector Machine     51.29
# 1           Random Forest     50.93
# 2     Logistic Regression     50.14
# 3           Decision Tree     50.14
# 4     K-Nearest Neighbors     49.43

# %%
# Check correlation of features with target

correlation = df.corr(numeric_only=True)["Heart Attack Risk"].sort_values(
    ascending=False
)

print(correlation)
# Out:
# Heart Attack Risk                    1.000000
# Gender                               0.030588
# Hypertension History                 0.027147
# Obesity (BMI > 30)                   0.020848
# Smoking History                      0.011718
# Age                                  0.009113
# Old Peak (ST Depression)             0.006353
# Fasting Blood Sugar (> 120 mg/dL)    0.005728
# Diabetes History                     0.005726
# Chest Pain Type                      0.004078
# Exercise-Induced Angina              0.001992
# Thalassemia                          0.001769
# Alcohol Consumption                  0.000019
# Family History of Heart Disease     -0.000283
# Max Heart Rate Achieved             -0.001598
# Number of Major Vessels (0-3)       -0.001797
# Slope of Peak Exercise ST Segment   -0.004710
# Resting Blood Pressure              -0.008443
# Stress Levels                       -0.010907
# Cholesterol                         -0.011376
# ...

# %%
# Random Forest feature importance

rf_model = trained_models["Random Forest"]

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
}).sort_values(
    by="Importance",
    ascending=False
)

feature_importance
# Out:
#                               Feature  Importance
# 9            Old Peak (ST Depression)    0.123897
# 4                         Cholesterol    0.123689
# 7             Max Heart Rate Achieved    0.119793
# 3              Resting Blood Pressure    0.116547
# 0                                 Age    0.113409
# 11      Number of Major Vessels (0-3)    0.044030
# 2                     Chest Pain Type    0.043812
# 19                      Stress Levels    0.034101
# 10  Slope of Peak Exercise ST Segment    0.033688
# 12                        Thalassemia    0.033444
# 5   Fasting Blood Sugar (> 120 mg/dL)    0.021134
# 14                 Obesity (BMI > 30)    0.020818
# 17                Alcohol Consumption    0.020624
# 8             Exercise-Induced Angina    0.020537
# 16                   Diabetes History    0.020503
# 13                    Smoking History    0.020427
# 18                  Physical Activity    0.020211
# 20    Family History of Heart Disease    0.020069
# ...

# %%
from sklearn.metrics import classification_report

best_model = trained_models["Support Vector Machine"]

y_pred = best_model.predict(X_test_scaled)

print("Support Vector Machine - Classification Report")
print("=" * 55)

print(classification_report(y_test, y_pred))
# Out:
# Support Vector Machine - Classification Report
# ...
#               precision    recall  f1-score   support
#
#            0       0.51      0.48      0.50       699
#            1       0.51      0.54      0.53       701
#
#     accuracy                           0.51      1400
#    macro avg       0.51      0.51      0.51      1400
# weighted avg       0.51      0.51      0.51      1400

# %%
# Sample Patient Prediction

sample = X_test.iloc[0:1]

sample_scaled = scaler.transform(sample)

prediction = best_model.predict(sample_scaled)

print("Sample Patient Prediction")
print("=" * 40)

if prediction[0] == 1:
    print("Prediction: HIGH HEART ATTACK RISK")
else:
    print("Prediction: LOW HEART ATTACK RISK")
# Out:
# Sample Patient Prediction
# ...
# Prediction: HIGH HEART ATTACK RISK

# %%
import joblib

# Save the trained model
joblib.dump(best_model, "heart_attack_risk_model.pkl")

# Save the scaler
joblib.dump(scaler, "heart_attack_scaler.pkl")

print("Model saved successfully!")
print("Scaler saved successfully!")
# Out:
# Model saved successfully!
# Scaler saved successfully!

# %%
import joblib

joblib.dump(best_model, "heart_attack_risk_model.pkl")
joblib.dump(scaler, "heart_attack_scaler.pkl")

print("Model saved successfully!")
print("Scaler saved successfully!")
# Out:
# Model saved successfully!
# Scaler saved successfully!

# %%
import os

print("Current Folder:")
print(os.getcwd())

print("\nFiles in this folder:")
print(os.listdir())
# Out:
# Current Folder:
# C:\Users\asoka
#
# Files in this folder:
# ...

# %%
import os

project_path = r"E:\Heart Attack Prediction"

os.chdir(project_path)

print("Current Working Directory:")
print(os.getcwd())
# Out:
# Current Working Directory:
# E:\Heart Attack Prediction

# %%
import joblib

joblib.dump(best_model, "heart_attack_risk_model.pkl")
joblib.dump(scaler, "heart_attack_scaler.pkl")

print("Model and scaler saved successfully!")
# Out:
# Model and scaler saved successfully!

# %%
import os
import pandas as pd

project_path = r"E:\Heart Attack Prediction"

print("Folder exists:", os.path.exists(project_path))

csv_files = [
    f for f in os.listdir(project_path)
    if f.lower().endswith(".csv")
]

print("CSV files found:")
for f in csv_files:
    print(f)
# Out:
# Folder exists: True
# CSV files found:
# heart_attack_prediction_india.csv

# %%
csv_files = [
    f for f in os.listdir(project_path)
    if f.lower().endswith(".csv")
]

if len(csv_files) == 1:
    csv_path = os.path.join(project_path, csv_files[0])
    df = pd.read_csv(csv_path)

    print("Dataset loaded successfully!")
    print("File:", csv_files[0])
    print("Shape:", df.shape)
else:
    print("CSV files found:", csv_files)
# Out:
# Dataset loaded successfully!
# File: heart_attack_prediction_india.csv
# Shape: (7000, 22)

# %%
df.head()
# Out:
#    Age  Gender  Chest Pain Type  Resting Blood Pressure  Cholesterol  \
# 0   69       0                4                     109          487
# 1   32       0                2                     125          170
# 2   89       0                2                     186          543
# 3   78       0                2                     104          367
# 4   38       1                1                     151          158
#
#    Fasting Blood Sugar (> 120 mg/dL)  Resting ECG Results  \
# 0                                  1                    1
# 1                                  0                    1
# 2                                  1                    0
# 3                                  0                    0
# 4                                  1                    0
#
#    Max Heart Rate Achieved  Exercise-Induced Angina  Old Peak (ST Depression)  \
# 0                      122                        1                      3.51
# ...

# %%
print("DATASET INFORMATION")
print("=" * 50)

print("Rows:", df.shape[0])
print("Columns:", df.shape[1])

print("\nColumn Names:")
for i, column in enumerate(df.columns, 1):
    print(i, ":", column)

print("\nData Types:")
print(df.dtypes)

print("\nMissing Values:")
print(df.isnull().sum().sum())

print("\nDuplicate Rows:")
print(df.duplicated().sum())
# Out:
# DATASET INFORMATION
# ...
# Rows: 7000
# Columns: 22
#
# Column Names:
# 1 : Age
# 2 : Gender
# 3 : Chest Pain Type
# 4 : Resting Blood Pressure
# 5 : Cholesterol
# 6 : Fasting Blood Sugar (> 120 mg/dL)
# 7 : Resting ECG Results
# 8 : Max Heart Rate Achieved
# 9 : Exercise-Induced Angina
# 10 : Old Peak (ST Depression)
# 11 : Slope of Peak Exercise ST Segment
# 12 : Number of Major Vessels (0-3)
# 13 : Thalassemia
# 14 : Smoking History
# 15 : Obesity (BMI > 30)
# 16 : Hypertension History
# 17 : Diabetes History
# 18 : Alcohol Consumption
# 19 : Physical Activity
# 20 : Stress Levels
# 21 : Family History of Heart Disease
# 22 : Heart Attack Risk
#
# Data Types:
# Age                                    int64
# Gender                                 int64
# Chest Pain Type                        int64
# Resting Blood Pressure                 int64
# Cholesterol                            int64
# Fasting Blood Sugar (> 120 mg/dL)      int64
# Resting ECG Results                    int64
# ...

# %%
import os

print(os.getcwd())
print("\nProject Files:")
for file in os.listdir(r"E:\Heart Attack Prediction"):
    print(file)
# Out:
# E:\Heart Attack Prediction
#
# Project Files:
# heart_attack_prediction_india.csv
# heart_attack_risk_model.pkl
# heart_attack_scaler.pkl

# %%
import os

print(os.path.abspath("Heart_Attack_Risk_Prediction.ipynb"))
# Out:
# C:\Users\asoka\Heart_Attack_Risk_Prediction.ipynb

# %%
import os

print("Current working folder:")
print(os.getcwd())
# Out:
# Current working folder:
# C:\Users\asoka

# %%
import os

notebook_name = "Heart_Attack_Risk_Prediction.ipynb"

matches = []

for root, dirs, files in os.walk(os.path.expanduser("~")):
    if notebook_name in files:
        matches.append(os.path.join(root, notebook_name))

print("Notebook found at:")
for path in matches:
    print(path)
# Out:
# Notebook found at:
# C:\Users\asoka\Heart_Attack_Risk_Prediction.ipynb

# %%
import os

print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\asoka
# ...
